# %%
genes_Yengo=read.table('/dagher/dagher11/filip/Downloads/near_gens_1be7b28a.txt', sep='\t', header=T)
genes_Yengo[genes_Yengo=='None']=NA

# %%
a=unique(genes_Yengo$Overlapped.Gene)

# %%
print(a)
# Out:
#   [1] "NADK"           "PANK4"          "DNAJC11"        "RERE"
#   [5] "MTOR"           "DDI2"           NA               "MFAP2"
#   [9] "UBR4"           "KDM1A"          "AL031428.1"     "S100PBP"
#  [13] "A3GALT2"        "AL513327.1"     "CSMD2"          "GNL2"
#  [17] "MACF1"          "ZSWIM5"         "MAST2"          "AGBL4"
#  [21] "PATJ"           "LEPR"           "FPGT-TNNI3K"    "TNNI3K"
#  [25] "PIGK"           "ADGRL2"         "EVI5"           "DPYD"
#  [29] "NTNG1"          "GPR61"          "AL355310.3"     "GNAI3"
#  [33] "KCND3"          "BNIPL"          "DCST2"          "AL355388.3"
#  [37] "SSR2"           "POU2F1"         "SLC9C2"         "AL139142.1"
#  [41] "AL121983.2"     "RABGAP1L"       "CACYBP"         "MRPS14"
#  [45] "BRINP3"         "AL354771.1"     "F13B"           "IPO9"
#  [49] "PTPN7"          "SLC41A1"        "LINC01698"      "SDCCAG8"
#  [53] "AKT3"           "AL713851.1"     "RSU1"           "MALRD1"
# ...

# %%
write.table(a,'/dagher/dagher11/filip/Obesity_maps//data/Yengo_genes.csv', sep=',', quote=F, row.names=F)
