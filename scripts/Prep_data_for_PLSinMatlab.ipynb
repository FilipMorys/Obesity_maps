# %% [markdown]
# # Gene analysis

# %% [markdown]
# ## Get genetics data

# %%
import abagen
atlas = abagen.fetch_desikan_killiany()

# %%
files = abagen.fetch_microarray(data_dir='/dagher/dagher9/filip/', donors='all', verbose=0)

# %%
expression_DKT = abagen.get_expression_data('/dagher/dagher11/filip/Downloads/OASIS-TRT-20_jointfusion_DKT31_CMA_labels_in_MNI152_2mm_v2.nii.gz',
                                            data_dir='dagher/dagher9/filip/',
                                            missing='interpolate')

# %%
import numpy as np
np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/expression_DKT.csv',expression_DKT, delimiter=',',fmt='%f')

# %%
np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/abagenes.csv',list(expression_DKT.columns), delimiter=',',
          fmt='%s')

# %% [markdown]
# ## Use DKT parcellation for BMI data - DBM

# %%
from netneurotools import datasets as nntdatasets
from neuromaps import datasets as nmdatasets
from neuromaps.parcellate import Parcellater
import pandas as pd
from neuromaps import transforms
import neuromaps


#cammoun = nntdatasets.fetch_cammoun2012(version="MNI152NLin2009aSym")
#info = pd.read_csv(cammoun['info'])
#labels = info.query('scale=="scale033"')['label']  # or might be "labels"

#parc = Parcellater(cammoun['scale033'], 'mni152')  # assuming mymap is in mni152 space
BMI = neuromaps.images.load_nifti('/dagher/dagher9/filip/DBM/HCP_DBM_Slvl/beta_0003.nii')

#mymap = nmdatasets.fetch_annotation(source='/dagher/dagher11/filip/Obesity_maps/data/BMI_lh.gii')
parc = Parcellater('/dagher/dagher11/filip/Downloads/OASIS-TRT-20_jointfusion_DKT31_CMA_labels_in_MNI152_2mm_v2.nii.gz', 
                   'mni152')  # assuming mymap is in mni152 space
mymap_parc = parc.fit_transform(BMI, 'mni152')

np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/BMI_DBM_DKT.csv', mymap_parc, delimiter=',', fmt='%f')

# %%
(list(expression_DKT.columns))
# Out:
# ['A1BG',
#  'A1BG-AS1',
#  'A2M',
#  'A2ML1',
#  'A3GALT2',
#  'A4GALT',
#  'AAAS',
#  'AACS',
#  'AADACL3',
#  'AADAT',
#  'AAED1',
#  'AAGAB',
#  'AAK1',
#  'AAMDC',
#  'AAMP',
#  'AANAT',
#  'AAR2',
#  'AARD',
#  'AARS',
#  'AARS2',
#  'AASDH',
#  'AASDHPPT',
#  'AASS',
#  'AATF',
#  'AATK',
#  'ABAT',
#  'ABCA1',
#  'ABCA10',
#  'ABCA11P',
#  'ABCA2',
#  'ABCA3',
#  'ABCA5',
#  'ABCA6',
#  'ABCA7',
#  'ABCA8',
#  'ABCA9',
#  'ABCB1',
#  'ABCB10',
#  'ABCB6',
#  'ABCB7',
#  'ABCB8',
#  'ABCB9',
#  'ABCC1',
#  'ABCC10',
#  'ABCC12',
#  'ABCC5',
#  'ABCC6',
#  'ABCC8',
#  'ABCC9',
#  'ABCD2',
#  'ABCD3',
#  'ABCD4',
#  'ABCE1',
#  'ABCF1',
#  'ABCF2',
#  'ABCF3',
#  'ABCG1',
#  'ABCG2',
#  'ABCG4',
#  'ABCG8',
#  'ABHD1',
#  'ABHD10',
#  'ABHD11',
#  'ABHD12',
#  'ABHD12B',
#  'ABHD13',
#  'ABHD14A',
#  'ABHD14B',
#  'ABHD16A',
#  'ABHD16B',
#  'ABHD17A',
#  'ABHD17B',
#  'ABHD17C',
#  'ABHD18',
#  'ABHD2',
#  'ABHD3',
#  'ABHD4',
#  'ABHD5',
#  'ABHD6',
#  'ABHD8',
#  'ABI1',
#  'ABI2',
#  'ABI3',
#  'ABL1',
#  'ABL2',
#  'ABLIM1',
#  'ABLIM2',
#  'ABLIM3',
#  'ABR',
#  'ABRACL',
#  'ABRAXAS2',
#  'ABT1',
#  'ABTB1',
#  'ABTB2',
#  'ACAA1',
#  'ACAA2',
#  'ACACA',
#  'ACACB',
#  'ACAD10',
#  'ACAD11',
#  'ACAD8',
#  'ACAD9',
#  'ACADL',
#  'ACADM',
#  'ACADSB',
#  'ACADVL',
#  'ACAN',
#  'ACAP2',
#  'ACAP3',
#  'ACAT1',
#  'ACAT2',
#  'ACBD3',
#  'ACBD4',
#  'ACBD5',
#  'ACBD6',
#  'ACBD7',
#  'ACCS',
#  'ACD',
#  'ACE',
#  'ACER2',
#  'ACER3',
#  'ACHE',
#  'ACIN1',
#  'ACKR1',
#  'ACKR2',
#  'ACKR3',
#  'ACKR4',
#  'ACLY',
#  'ACO1',
#  'ACO2',
#  'ACOT11',
#  'ACOT13',
#  'ACOT2',
#  'ACOT4',
#  'ACOT7',
#  'ACOT8',
#  'ACOT9',
#  'ACOX1',
#  'ACOX2',
#  'ACOX3',
#  'ACP1',
#  'ACP2',
#  'ACP5',
#  'ACP6',
#  'ACPP',
#  'ACR',
#  'ACRBP',
#  'ACSBG1',
#  'ACSF2',
#  'ACSF3',
#  'ACSL1',
#  'ACSL3',
#  'ACSL4',
#  'ACSL6',
#  'ACSM1',
#  'ACSM2A',
#  'ACSM5',
#  'ACSS1',
#  'ACSS2',
#  'ACSS3',
#  'ACTA1',
#  'ACTA2',
#  'ACTB',
#  'ACTBL2',
#  'ACTC1',
#  'ACTG1',
#  'ACTG1P4',
#  'ACTG2',
#  'ACTL10',
#  'ACTL6A',
#  'ACTL6B',
#  'ACTL8',
#  'ACTN1',
#  'ACTN2',
#  'ACTN4',
#  'ACTR10',
#  'ACTR1A',
#  'ACTR1B',
#  'ACTR2',
#  'ACTR3',
#  'ACTR3B',
#  'ACTR3BP2',
#  'ACTR3C',
#  'ACTR5',
#  'ACTR6',
#  'ACTR8',
#  'ACTRT3',
#  'ACVR1',
#  'ACVR1B',
#  'ACVR1C',
#  'ACVR2A',
#  'ACVR2B',
#  'ACVRL1',
#  'ACY3',
#  'ACYP1',
#  'ACYP2',
#  'ADA',
#  'ADA2',
#  'ADAD2',
#  'ADAL',
#  'ADAM10',
#  'ADAM11',
#  'ADAM15',
#  'ADAM17',
#  'ADAM19',
#  'ADAM20',
#  'ADAM20P1',
#  'ADAM22',
#  'ADAM23',
#  'ADAM28',
#  'ADAM29',
#  'ADAM33',
#  'ADAM7',
#  'ADAM8',
#  'ADAM9',
#  'ADAMTS1',
#  'ADAMTS10',
#  'ADAMTS13',
#  'ADAMTS14',
#  'ADAMTS19',
#  'ADAMTS2',
#  'ADAMTS4',
#  'ADAMTS5',
#  'ADAMTS7',
#  'ADAMTS8',
#  'ADAMTS9',
#  'ADAMTSL1',
#  'ADAMTSL2',
#  'ADAMTSL3',
#  'ADAMTSL5',
#  'ADAP1',
#  'ADAP2',
#  'ADAR',
#  'ADARB1',
#  'ADARB2',
#  'ADARB2-AS1',
#  'ADAT1',
#  'ADAT2',
#  'ADAT3',
#  'ADCK1',
#  'ADCK2',
#  'ADCK5',
#  'ADCY1',
#  'ADCY10P1',
#  'ADCY2',
#  'ADCY3',
#  'ADCY4',
#  'ADCY5',
#  'ADCY6',
#  'ADCY7',
#  'ADCY8',
#  'ADCY9',
#  'ADCYAP1',
#  'ADCYAP1R1',
#  'ADD1',
#  'ADD2',
#  'ADD3',
#  'ADGRA1',
#  'ADGRA2',
#  'ADGRA3',
#  'ADGRB1',
#  'ADGRB2',
#  'ADGRB3',
#  'ADGRE5',
#  'ADGRF5',
#  'ADGRG1',
#  'ADGRG5',
#  'ADGRG6',
#  'ADGRL1',
#  'ADGRL2',
#  'ADGRL3',
#  'ADGRL4',
#  'ADGRV1',
#  'ADH1C',
#  'ADH5',
#  'ADHFE1',
#  'ADI1',
#  'ADIPOR1',
#  'ADIPOR2',
#  'ADIRF',
#  'ADK',
#  'ADM',
#  'ADM5',
#  'ADNP',
#  'ADNP-AS1',
#  'ADNP2',
#  'ADO',
#  'ADORA1',
#  'ADORA2B',
#  'ADPGK',
#  'ADPRHL1',
#  'ADPRHL2',
#  'ADPRM',
#  'ADRA1A',
#  'ADRA1B',
#  'ADRA1D',
#  'ADRA2A',
#  'ADRA2C',
#  'ADRB1',
#  'ADRB2',
#  'ADRM1',
#  'ADSL',
#  'ADSS',
#  'ADSSL1',
#  'ADTRP',
#  'AEBP1',
#  'AEBP2',
#  'AES',
#  'AFAP1',
#  'AFAP1L1',
#  'AFAP1L2',
#  'AFDN',
#  'AFDN-DT',
#  'AFF1',
#  'AFF2',
#  'AFF3',
#  'AFF4',
#  'AFG1L',
#  'AFG3L1P',
#  'AFG3L2',
#  'AFMID',
#  'AFTPH',
#  'AGA',
#  'AGAP1',
#  'AGAP11',
#  'AGAP2',
#  'AGAP2-AS1',
#  'AGAP3',
#  'AGAP5',
#  'AGBL2',
#  'AGBL3',
#  'AGBL4',
#  'AGBL5',
#  'AGER',
#  'AGFG1',
#  'AGFG2',
#  'AGGF1',
#  'AGK',
#  'AGL',
#  'AGMAT',
#  'AGO1',
#  'AGO2',
#  'AGO3',
#  'AGO4',
#  'AGPAT1',
#  'AGPAT3',
#  'AGPAT4',
#  'AGPAT4-IT1',
#  'AGPAT5',
#  'AGPS',
#  'AGRN',
#  'AGT',
#  'AGTPBP1',
#  'AGTRAP',
#  'AGXT',
#  'AHCTF1',
#  'AHCY',
#  'AHCYL1',
#  'AHCYL2',
#  'AHDC1',
#  'AHI1',
#  'AHNAK',
#  'AHNAK2',
#  'AHR',
#  'AHRR',
#  'AHSA1',
#  'AHSA2P',
#  'AHSG',
#  'AIDA',
#  'AIF1',
#  'AIF1L',
#  'AIFM1',
#  'AIFM2',
#  'AIFM3',
#  'AIG1',
#  'AIM2',
#  'AIMP1',
#  'AIMP2',
#  'AIP',
#  'AIRE',
#  'AJAP1',
#  'AJM1',
#  'AK1',
#  'AK2',
#  'AK3',
#  'AK4',
#  'AK5',
#  'AK6',
#  'AK8',
#  'AK9',
#  'AKAIN1',
#  'AKAP1',
#  'AKAP10',
#  'AKAP11',
#  'AKAP12',
#  'AKAP13',
#  'AKAP17A',
#  'AKAP5',
#  'AKAP6',
#  'AKAP7',
#  'AKAP8',
#  'AKAP8L',
#  'AKAP9',
#  'AKIP1',
#  'AKIRIN1',
#  'AKIRIN2',
#  'AKR1A1',
#  'AKR1B1',
#  'AKR1C1',
#  'AKR1C3',
#  'AKR1C4',
#  'AKR1E2',
#  'AKR7A2',
#  'AKR7A2P1',
#  'AKR7A3',
#  'AKR7L',
#  'AKT1',
#  'AKT1S1',
#  'AKT2',
#  'AKT3',
#  'AKTIP',
#  'ALAD',
#  'ALAS1',
#  'ALAS2',
#  'ALB',
#  'ALCAM',
#  'ALDH16A1',
#  'ALDH18A1',
#  'ALDH1A1',
#  'ALDH1A3',
#  'ALDH1B1',
#  'ALDH1L1',
#  'ALDH1L2',
#  'ALDH2',
#  'ALDH3A2',
#  'ALDH3B1',
#  'ALDH4A1',
#  'ALDH5A1',
#  'ALDH6A1',
#  'ALDH7A1',
#  'ALDH8A1',
#  'ALDH9A1',
#  'ALDOA',
#  'ALDOC',
#  'ALG1',
#  'ALG10',
#  'ALG10B',
#  'ALG11',
#  'ALG12',
#  'ALG13',
#  'ALG14',
#  'ALG1L',
#  'ALG2',
#  'ALG3',
#  'ALG5',
#  'ALG6',
#  'ALG8',
#  'ALG9',
#  'ALK',
#  'ALKAL1',
#  'ALKAL2',
#  'ALKBH1',
#  'ALKBH2',
#  'ALKBH3',
#  'ALKBH4',
#  'ALKBH5',
#  'ALKBH6',
#  'ALKBH7',
#  'ALKBH8',
#  'ALMS1',
#  'ALMS1P1',
#  'ALOX12B',
#  'ALOX12P2',
#  'ALOX15B',
#  'ALOX5',
#  'ALOX5AP',
#  'ALOXE3',
#  'ALPK1',
#  'ALPL',
#  'ALPP',
#  'ALPPL2',
#  'ALS2',
#  'ALS2CL',
#  'ALS2CR12',
#  'ALX3',
#  'ALYREF',
#  'AMACR',
#  'AMBRA1',
#  'AMD1',
#  'AMDHD1',
#  'AMDHD2',
#  'AMER1',
#  'AMER2',
#  'AMER3',
#  'AMFR',
#  'AMH',
#  'AMIGO1',
#  'AMIGO2',
#  'AMIGO3',
#  'AMMECR1',
#  'AMMECR1L',
#  'AMN',
#  'AMN1',
#  'AMOT',
#  'AMOTL1',
#  'AMOTL2',
#  'AMPD2',
#  'AMPD3',
#  'AMPH',
#  'AMT',
#  'AMY2A',
#  'AMZ1',
#  'AMZ2',
#  'AMZ2P1',
#  'ANAPC1',
#  'ANAPC10',
#  'ANAPC11',
#  'ANAPC13',
#  'ANAPC15',
#  'ANAPC16',
#  'ANAPC2',
#  'ANAPC4',
#  'ANAPC5',
#  'ANAPC7',
#  'ANG',
#  'ANGEL1',
#  'ANGEL2',
#  'ANGPT1',
#  'ANGPT2',
#  'ANGPT4',
#  'ANGPTL2',
#  'ANGPTL4',
#  'ANGPTL6',
#  'ANHX',
#  'ANK1',
#  'ANK2',
#  'ANK3',
#  'ANKAR',
#  'ANKDD1A',
#  'ANKFY1',
#  'ANKH',
#  'ANKHD1',
#  'ANKIB1',
#  'ANKK1',
#  'ANKLE2',
#  'ANKMY2',
#  'ANKRA2',
#  'ANKRD10',
#  'ANKRD11',
#  'ANKRD12',
#  'ANKRD13A',
#  'ANKRD13B',
#  'ANKRD13C',
#  'ANKRD13D',
#  'ANKRD16',
#  'ANKRD17',
#  'ANKRD18A',
#  'ANKRD18B',
#  'ANKRD18CP',
#  'ANKRD18DP',
#  'ANKRD19P',
#  'ANKRD2',
#  'ANKRD20A11P',
#  'ANKRD20A12P',
#  'ANKRD20A4-ANKRD20A20P',
#  'ANKRD20A5P',
#  'ANKRD20A8P',
#  'ANKRD20A9P',
#  'ANKRD23',
#  'ANKRD24',
#  'ANKRD26',
#  'ANKRD27',
#  'ANKRD28',
#  'ANKRD29',
#  'ANKRD30B',
#  'ANKRD30BP2',
#  'ANKRD33',
#  'ANKRD33B',
#  'ANKRD34A',
#  'ANKRD34C',
#  'ANKRD35',
#  'ANKRD36B',
#  'ANKRD36BP1',
#  'ANKRD36BP2',
#  'ANKRD36C',
#  'ANKRD37',
#  'ANKRD39',
#  'ANKRD40',
#  'ANKRD42',
#  'ANKRD44',
#  'ANKRD45',
#  'ANKRD46',
#  'ANKRD49',
#  'ANKRD50',
#  'ANKRD52',
#  'ANKRD53',
#  'ANKRD54',
#  'ANKRD6',
#  'ANKRD65',
#  'ANKRD9',
#  'ANKS1A',
#  'ANKS1B',
#  'ANKS3',
#  'ANKS6',
#  'ANKZF1',
#  'ANLN',
#  'ANO10',
#  'ANO2',
#  'ANO3',
#  'ANO4',
#  'ANO5',
#  'ANO6',
#  'ANO7',
#  'ANO8',
#  'ANOS1',
#  'ANP32A',
#  'ANP32A-IT1',
#  'ANP32AP1',
#  'ANP32B',
#  'ANP32C',
#  'ANP32D',
#  'ANP32E',
#  'ANTXR1',
#  'ANTXR2',
#  'ANXA1',
#  'ANXA11',
#  'ANXA2',
#  'ANXA2P1',
#  'ANXA2R',
#  'ANXA3',
#  'ANXA4',
#  'ANXA5',
#  'ANXA6',
#  'ANXA7',
#  'AOAH',
#  'AOC2',
#  'AOC3',
#  'AP1AR',
#  'AP1B1',
#  'AP1G1',
#  'AP1G2',
#  'AP1M1',
#  'AP1S1',
#  'AP1S2',
#  'AP1S3',
#  'AP2A1',
#  'AP2A2',
#  'AP2B1',
#  'AP2M1',
#  'AP2S1',
#  'AP3B1',
#  'AP3B2',
#  'AP3D1',
#  'AP3M1',
#  'AP3M2',
#  'AP3S1',
#  'AP4B1',
#  'AP4E1',
#  'AP4M1',
#  'AP4S1',
#  'AP5B1',
#  'AP5M1',
#  'AP5S1',
#  'AP5Z1',
#  'APAF1',
#  'APBA1',
#  'APBA2',
#  'APBA3',
#  'APBB1',
#  'APBB1IP',
#  'APBB2',
#  'APBB3',
#  'APC',
#  'APC2',
#  'APCDD1',
#  'APCDD1L',
#  'APCS',
#  'APEH',
#  'APEX1',
#  'APEX2',
#  'APH1A',
#  'APH1B',
#  'API5',
#  'APIP',
#  'APLN',
#  'APLNR',
#  'APLP1',
#  'APLP2',
#  'APMAP',
#  'APOA1',
#  'APOC1',
#  'APOD',
#  'APOE',
#  'APOL1',
#  'APOL2',
#  'APOL3',
#  'APOL4',
#  'APOL5',
#  'APOL6',
#  'APOLD1',
#  'APOM',
#  'APOO',
#  'APOOL',
#  'APOPT1',
#  'APP',
#  'APPBP2',
#  'APPL1',
#  'APPL2',
#  'APRT',
#  'APTR',
#  'APTX',
#  'AQP1',
#  'AQP11',
#  'AQP2',
#  'AQP4',
#  'AQP5',
#  'AQP6',
#  'AQP7',
#  'AQP7P1',
#  'AQR',
#  'AR',
#  'ARAF',
#  'ARAP1',
#  'ARAP2',
#  'ARAP3',
#  'ARC',
#  'ARCN1',
#  'AREL1',
#  'ARF1',
#  'ARF3',
#  'ARF4',
#  'ARF5',
#  'ARF6',
#  'ARFGAP1',
#  'ARFGAP2',
#  'ARFGAP3',
#  'ARFGEF1',
#  'ARFGEF2',
#  'ARFGEF3',
#  'ARFIP1',
#  'ARFIP2',
#  'ARFRP1',
#  'ARG2',
#  'ARGLU1',
#  'ARHGAP1',
#  'ARHGAP10',
#  'ARHGAP12',
#  'ARHGAP17',
#  'ARHGAP18',
#  'ARHGAP19',
#  'ARHGAP20',
#  'ARHGAP21',
#  'ARHGAP22',
#  'ARHGAP23',
#  'ARHGAP24',
#  'ARHGAP25',
#  'ARHGAP26',
#  'ARHGAP27',
#  'ARHGAP27P1',
#  'ARHGAP27P1-BPTFP1-KPNA2P3',
#  'ARHGAP27P2',
#  'ARHGAP28',
#  'ARHGAP29',
#  'ARHGAP31',
#  'ARHGAP32',
#  'ARHGAP33',
#  'ARHGAP35',
#  'ARHGAP36',
#  'ARHGAP39',
#  'ARHGAP4',
#  'ARHGAP42',
#  'ARHGAP44',
#  'ARHGAP45',
#  'ARHGAP5',
#  'ARHGAP5-AS1',
#  'ARHGAP6',
#  'ARHGAP9',
#  'ARHGDIA',
#  'ARHGDIB',
#  'ARHGDIG',
#  'ARHGEF1',
#  'ARHGEF10',
#  'ARHGEF10L',
#  'ARHGEF11',
#  'ARHGEF12',
#  'ARHGEF15',
#  'ARHGEF16',
#  'ARHGEF17',
#  'ARHGEF18',
#  'ARHGEF19',
#  'ARHGEF2',
#  'ARHGEF25',
#  'ARHGEF26',
#  'ARHGEF26-AS1',
#  'ARHGEF28',
#  'ARHGEF3',
#  'ARHGEF33',
#  'ARHGEF37',
#  'ARHGEF4',
#  'ARHGEF40',
#  'ARHGEF6',
#  'ARHGEF7',
#  'ARHGEF9',
#  'ARID1A',
#  'ARID1B',
#  'ARID2',
#  'ARID3A',
#  'ARID3B',
#  'ARID4A',
#  'ARID4B',
#  'ARID5A',
#  'ARID5B',
#  'ARIH1',
#  'ARIH2',
#  'ARIH2OS',
#  'ARL1',
#  'ARL10',
#  'ARL13B',
#  'ARL14EP',
#  'ARL15',
#  'ARL16',
#  'ARL17A',
#  'ARL17B',
#  'ARL2',
#  'ARL2BP',
#  'ARL3',
#  'ARL4A',
#  'ARL4C',
#  'ARL4D',
#  'ARL5A',
#  'ARL5B',
#  'ARL6',
#  'ARL6IP1',
#  'ARL6IP4',
#  'ARL6IP5',
#  'ARL6IP6',
#  'ARL8A',
#  'ARL8B',
#  'ARL9',
#  'ARMC1',
#  'ARMC10',
#  'ARMC2',
#  'ARMC5',
#  'ARMC6',
#  'ARMC7',
#  'ARMC8',
#  'ARMC9',
#  'ARMCX1',
#  'ARMCX2',
#  'ARMCX3',
#  'ARMCX4',
#  'ARMCX5',
#  'ARMCX6',
#  'ARMT1',
#  'ARNT',
#  'ARNT2',
#  'ARNTL',
#  'ARNTL2',
#  'ARPC1A',
#  'ARPC1B',
#  'ARPC2',
#  'ARPC3',
#  'ARPC4',
#  'ARPC5',
#  'ARPC5L',
#  'ARPIN',
#  'ARPP19',
#  'ARPP21',
#  'ARRB1',
#  'ARRB2',
#  'ARRDC1',
#  'ARRDC1-AS1',
#  'ARRDC2',
#  'ARRDC3',
#  'ARRDC4',
#  'ARSA',
#  'ARSB',
#  'ARSD',
#  'ARSE',
#  'ARSF',
#  'ARSG',
#  'ARSJ',
#  'ARSK',
#  'ART3',
#  'ART5',
#  'ARTN',
#  'ARV1',
#  'ARVCF',
#  'ARX',
#  'ASAH1',
#  'ASAH2',
#  'ASAH2B',
#  'ASAP1',
#  'ASAP1-IT1',
#  'ASAP1-IT2',
#  'ASAP2',
#  'ASAP3',
#  'ASB1',
#  'ASB10',
#  'ASB13',
#  'ASB16',
#  'ASB16-AS1',
#  'ASB18',
#  'ASB2',
#  'ASB4',
#  'ASB5',
#  'ASB6',
#  'ASB7',
#  'ASB8',
#  'ASCC1',
#  'ASCC2',
#  'ASCC3',
#  'ASCL1',
#  'ASCL2',
#  'ASCL5',
#  'ASF1A',
#  'ASGR1',
#  'ASGR2',
#  'ASH1L',
#  'ASH1L-AS1',
#  'ASH2L',
#  'ASIC1',
#  'ASIC2',
#  'ASIC3',
#  'ASIC4',
#  'ASIP',
#  'ASL',
#  'ASMTL',
#  'ASMTL-AS1',
#  'ASNA1',
#  'ASNSD1',
#  'ASNSP1',
#  'ASPA',
#  'ASPDH',
#  'ASPH',
#  'ASPHD1',
#  'ASPHD2',
#  'ASPRV1',
#  'ASPSCR1',
#  'ASRGL1',
#  'ASS1',
#  'ASTE1',
#  'ASTL',
#  'ASTN1',
#  'ASTN2',
#  'ASXL1',
#  'ASXL2',
#  'ASXL3',
#  'ATAD1',
#  'ATAD2',
#  'ATAD2B',
#  'ATAD3A',
#  'ATAD3B',
#  'ATAD3C',
#  'ATAD5',
#  'ATAT1',
#  'ATCAY',
#  'ATE1',
#  'ATF1',
#  'ATF2',
#  'ATF3',
#  'ATF4',
#  'ATF5',
#  'ATF6',
#  'ATF6B',
#  'ATF7',
#  'ATF7IP',
#  'ATF7IP2',
#  'ATG10',
#  'ATG101',
#  'ATG12',
#  'ATG13',
#  'ATG14',
#  'ATG16L1',
#  'ATG16L2',
#  'ATG2A',
#  'ATG2B',
#  'ATG3',
#  'ATG4A',
#  'ATG4B',
#  'ATG4C',
#  'ATG4D',
#  'ATG5',
#  'ATG7',
#  'ATG9A',
#  'ATIC',
#  'ATL1',
#  'ATL2',
#  'ATL3',
#  'ATM',
#  'ATMIN',
#  'ATN1',
#  'ATOH7',
#  'ATOH8',
#  'ATOX1',
#  'ATP10A',
#  'ATP10B',
#  'ATP10D',
#  'ATP11A',
#  'ATP11B',
#  ...]

# %% [markdown]
# ## Use Cammoun parcellation for BMI data - DBM

# %%
from netneurotools import datasets as nntdatasets
from neuromaps import datasets as nmdatasets
from neuromaps.parcellate import Parcellater
import pandas as pd
from neuromaps import transforms
import neuromaps
import numpy as np



cammoun = nntdatasets.fetch_cammoun2012(version="MNI152NLin2009aSym")
info = pd.read_csv(cammoun['info'])
labels = info.query('scale=="scale125"')['label']  # or might be "labels"

parc = Parcellater(cammoun['scale125'], 'mni152')  # assuming mymap is in mni152 space
BMI = neuromaps.images.load_nifti('/dagher/dagher9/filip/DBM/HCP_DBM_Slvl/beta_0003.nii')

mymap_parc = parc.fit_transform(BMI, 'mni152')

np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/BMI_DBM_Cammoun125.csv', mymap_parc[0][115:234], delimiter=',', fmt='%f')

# %%
type(mymap_parc)
# Out:
# numpy.ndarray
