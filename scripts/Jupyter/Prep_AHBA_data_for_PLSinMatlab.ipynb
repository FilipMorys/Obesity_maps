# %% [markdown]
# # Gene analysis

# %% [markdown]
# ## Get genetics data

# %%
import abagen
atlas = abagen.fetch_desikan_killiany()

# %%
files = abagen.fetch_microarray(data_dir='/dagher/dagher9/filip/', donors='all', verbose=0)

# %%
expression_DKT = abagen.get_expression_data('/dagher/dagher11/filip/Downloads/OASIS-TRT-20_jointfusion_DKT31_CMA_labels_in_MNI152_2mm_v2.nii.gz',
                                            data_dir='dagher/dagher9/filip/',
                                            missing='interpolate')
# Out:
# /dagher/dagher12/filip/software/miniconda3py/envs/py3/lib/python3.10/site-packages/abagen/probes_.py:66: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   reannotated.loc[:, 'entrez_id'] = reannotated['entrez_id'].astype('int')
# /dagher/dagher12/filip/software/miniconda3py/envs/py3/lib/python3.10/site-packages/abagen/probes_.py:757: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   micro = micro.set_axis(symbols, axis=1, inplace=False)
# ...

# %%
pd.set_option('display.max_rows', 500)
expression_DKT
# Out:
# gene_symbol      A1BG  A1BG-AS1       A2M     A2ML1   A3GALT2    A4GALT  \
# label
# 4            0.467001  0.241979  0.562175  0.645510  0.635516  0.567473
# 5            0.505112  0.408924  0.434041  0.539158  0.631222  0.580857
# 6            0.532365  0.399017  0.334089  0.440267  0.456985  0.453232
# 7            0.516784  0.228627  0.677912  0.572534  0.648151  0.625653
# 10           0.406815  0.220683  0.669152  0.569524  0.561747  0.577350
# 11           0.788399  0.425645  0.725498  0.587261  0.472289  0.579752
# 12           0.752544  0.382341  0.621301  0.567901  0.393274  0.583941
# 13           0.708084  0.278800  0.585201  0.592670  0.416663  0.467780
# 14           0.417575  0.201129  0.643622  0.472946  0.673287  0.584370
# 15           0.376253  0.227984  0.705517  0.583642  0.625109  0.598996
# 16           0.386625  0.234290  0.678508  0.598164  0.605992  0.558846
# 17           0.441299  0.345020  0.393948  0.603722  0.569828  0.601270
# ...

# %%
import numpy as np
np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/expression_DKT.csv',expression_DKT, delimiter=',',fmt='%f')

# %%
np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/abagenes.csv',list(expression_DKT.columns), delimiter=',',
          fmt='%s')

# %% [markdown]
# ## DKT for BMI-CT map in HCP

# %% [markdown]
# order of parcels = 1002
#         1003
#         1005
#         1006
#         1007
#         1008
#         1009
#         1010
#         1011
#         1012
#         1013
#         1014
#         1015
#         1016
#         1017
#         1018
#         1019
#         1020
#         1021
#         1022
#         1023
#         1024
#         1025
#         1026
#         1027
#         1028
#         1029
#         1030
#         1031
#         1034
#         1035
#         2002
#         2003
#         2005
#         2006
#         2007
#         2008
#         2009
#         2010
#         2011
#         2012
#         2013
#         2014
#         2015
#         2016
#         2017
#         2018
#         2019
#         2020
#         2021
#         2022
#         2023
#         2024
#         2025
#         2026
#         2027
#         2028
#         2029
#         2030
#         2031
#         2034
#         2035

# %% [markdown]
# structs=['caudalanteriorcingulate','caudalmiddlefrontal','cuneus','entorhinal','fusiform',
# 'inferiorparietal','inferiortemporal','isthmuscingulate','lateraloccipital','lateralorbitofrontal','lingual',
# 'medialorbitofrontal','middletemporal','parahippocampal','paracentral','parsopercularis',
# 'parsorbitalis','parstriangularis','pericalcarine','postcentral','posteriorcingulate','precentral',
# 'precuneus','rostralanteriorcingulate','rostralmiddlefrontal','superiorfrontal','superiorparietal',
# 'superiortemporal','supramarginal','transversetemporal','insula','caudalanteriorcingulate','caudalmiddlefrontal',
# 'cuneus','entorhinal','fusiform','inferiorparietal','inferiortemporal','isthmuscingulate','lateraloccipital',
# 'lateralorbitofrontal','lingual','medialorbitofrontal','middletemporal','parahippocampal',
# 'paracentral','parsopercularis','parsorbitalis','parstriangularis','pericalcarine','postcentral',
# 'posteriorcingulate','precentral','precuneus','rostralanteriorcingulate','rostralmiddlefrontal',
# 'superiorfrontal','superiorparietal','superiortemporal','supramarginal','transversetemporal','i

# %%
from netneurotools import datasets as nntdatasets
from neuromaps import datasets as nmdatasets
from neuromaps.parcellate import Parcellater
import pandas as pd
import neuromaps
from neuromaps import transforms
import numpy as np

dkt_gifti=neuromaps.images.annot_to_gifti('/dagher/dagher11/filip/Obesity_maps/data_old/DKT.annot')
parc = Parcellater(dkt_gifti, 'fsaverage', hemi='L')  # assuming mymap is in mni152 space
BMI=transforms.fsaverage_to_fsaverage('/dagher/dagher11/filip/Obesity_maps/data_old/BMI_lh.gii', '164k', hemi='L')
mymap_parc = parc.fit_transform(BMI, 'fsaverage', hemi='L')

np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/BMI_CT_DKT_LH.csv', mymap_parc, delimiter=',', fmt='%f')
# Out:
# /dagher/dagher12/filip/software/miniconda3py/envs/py3/lib/python3.10/site-packages/nilearn/input_data/__init__.py:27: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
import pandas
import scipy

#DKT_np=pandas.DataFrame.to_numpy(mymap_parc)
scipy.io.savemat('/dagher/dagher11/filip/Obesity_maps/data/BMI_CT_DKT_RH.mat', 
                 {'BMI_CT_DKT_RH': mymap_parc})

# %%
from netneurotools import datasets as nntdatasets
from neuromaps import datasets as nmdatasets
from neuromaps.parcellate import Parcellater
import pandas as pd
from neuromaps import transforms

dkt_gifti=neuromaps.images.annot_to_gifti('/dagher/dagher11/filip/Obesity_maps/data_old/rh.DKT.annot')
parc = Parcellater(dkt_gifti, 'fsaverage', hemi='R')  # assuming mymap is in mni152 space
BMI=transforms.fsaverage_to_fsaverage('/dagher/dagher11/filip/Obesity_maps/data_old/BMI_rh.gii', '164k', hemi='R')
mymap_parc = parc.fit_transform(BMI, 'fsaverage', hemi='R')

np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/BMI_CT_DKT_RH.csv', mymap_parc, delimiter=',', fmt='%f')

# %% [markdown]
# #### Sig maps

# %%
from netneurotools import datasets as nntdatasets
from neuromaps import datasets as nmdatasets
from neuromaps.parcellate import Parcellater
import pandas as pd
import neuromaps
from neuromaps import transforms
import numpy as np

dkt_gifti=neuromaps.images.annot_to_gifti('/dagher/dagher11/filip/Obesity_maps/data_old/DKT.annot')
parc = Parcellater(dkt_gifti, 'fsaverage', hemi='L')  # assuming mymap is in mni152 space
BMI=transforms.fsaverage_to_fsaverage('/dagher/dagher11/filip/Obesity_maps/data_old/sig_lh.gii', '164k', hemi='L')
mymap_parc = parc.fit_transform(BMI, 'fsaverage', hemi='L')

#mymap_parc=np.power(10,mymap_parc)

#np.savetxt('/dagher/dagher11/filip/Obesity_maps/tables/Sig_BMI_CT_DKT_LH.csv', mymap_parc, delimiter=',', fmt='%f')

# %%
#mymap_parc=np.power(mymap_parc,10)
mymap_parc**10
# Out:
# array([4.3905652e-01, 4.4095059e+03, 8.3849404e-04, 5.7600852e-04,
#        4.9809128e-04, 1.8260664e-01, 8.0135623e-03, 4.0112304e-06,
#        2.3478784e-03, 1.5383643e+02, 5.6391297e-21, 1.0202330e+01,
#        3.4824245e-07, 4.0145865e-06, 6.1680969e-02, 8.4737064e-03,
#        3.5292008e+00, 1.8038536e+01, 3.5476114e-06, 3.6251180e+00,
#        3.1199444e-05, 1.6779697e-01, 1.4118021e+01, 1.9189417e+02,
#        9.9593242e+03, 2.5389436e+02, 4.1450924e+01, 1.4822268e-11,
#        7.1101612e-04, 2.3065292e-08, 1.9199719e-08], dtype=float32)

# %%
import nibabel as nb

# %%
nb.gifti.gifti.GiftiImage(dkt_gifti)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [42], line 1
# ----> 1 nb.gifti.gifti.GiftiImage(dkt_gifti)
#
# File /dagher/dagher12/filip/software/miniconda3py/envs/py3/lib/python3.10/site-packages/nibabel/gifti/gifti.py:706, in GiftiImage.__init__(self, header, extra, file_map, meta, labeltable, darrays, version)
#     704 def __init__(self, header=None, extra=None, file_map=None, meta=None,
#     705              labeltable=None, darrays=None, version=u"1.0"):
# --> 706     super(GiftiImage, self).__init__(header=header, extra=extra,
#     707                                      file_map=file_map)
#     708     if darrays is None:
#     709         darrays = []
#
# File /dagher/dagher12/filip/software/miniconda3py/envs/py3/lib/python3.10/site-packages/nibabel/filebasedimages.py:192, in FileBasedImage.__init__(self, header, extra, file_map)
# ...

# %%
(dkt_gifti)
# Out:
# (<nibabel.gifti.gifti.GiftiImage at 0x7f31a755c880>,)

# %%
from netneurotools import datasets as nntdatasets
from neuromaps import datasets as nmdatasets
from neuromaps.parcellate import Parcellater
import pandas as pd
from neuromaps import transforms

dkt_gifti=neuromaps.images.annot_to_gifti('/dagher/dagher11/filip/Obesity_maps/data_old/rh.DKT.annot')
parc = Parcellater(dkt_gifti, 'fsaverage', hemi='R')  # assuming mymap is in mni152 space
BMI=transforms.fsaverage_to_fsaverage('/dagher/dagher11/filip/Obesity_maps/data_old/sig_rh.gii', '164k', hemi='R')
mymap_parc = parc.fit_transform(BMI, 'fsaverage', hemi='R')

np.savetxt('/dagher/dagher11/filip/Obesity_maps/tables/Sig_BMI_CT_DKT_RH.csv', mymap_parc, delimiter=',', fmt='%f')

# %% [markdown]
# ## DKT for BMI-CT map in HCP Aging

# %%
from netneurotools import datasets as nntdatasets
from neuromaps import datasets as nmdatasets
from neuromaps.parcellate import Parcellater
import pandas as pd
import neuromaps
from neuromaps import transforms
import numpy as np

dkt_gifti=neuromaps.images.annot_to_gifti('/dagher/dagher11/filip/Obesity_maps/data_old/DKT.annot')
parc = Parcellater(dkt_gifti, 'fsaverage', hemi='L')  # assuming mymap is in mni152 space
BMI=transforms.fsaverage_to_fsaverage('/dagher/dagher11/filip/Obesity_maps/data_old/BMI_HCPA_lh.gii', '164k', hemi='L')
mymap_parc = parc.fit_transform(BMI, 'fsaverage', hemi='L')

np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/HCPA_CT_DKT_LH.csv', mymap_parc, delimiter=',', fmt='%f')

# %%
import pandas
import scipy

#DKT_np=pandas.DataFrame.to_numpy(mymap_parc)
scipy.io.savemat('/dagher/dagher11/filip/Obesity_maps/data/HCPA_CT_DKT_LH.mat', 
                 {'HCPA_CT_DKT_LH': mymap_parc})

# %%
from netneurotools import datasets as nntdatasets
from neuromaps import datasets as nmdatasets
from neuromaps.parcellate import Parcellater
import pandas as pd
from neuromaps import transforms

dkt_gifti=neuromaps.images.annot_to_gifti('/dagher/dagher11/filip/Obesity_maps/data_old/rh.DKT.annot')
parc = Parcellater(dkt_gifti, 'fsaverage', hemi='R')  # assuming mymap is in mni152 space
BMI=transforms.fsaverage_to_fsaverage('/dagher/dagher11/filip/Obesity_maps/data_old/BMI_HCPA_rh.gii', '164k', hemi='R')
mymap_parc = parc.fit_transform(BMI, 'fsaverage', hemi='R')

np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/HCPA_CT_DKT_RH.csv', mymap_parc, delimiter=',', fmt='%f')

# %%
import pandas
import scipy

#DKT_np=pandas.DataFrame.to_numpy(mymap_parc)
scipy.io.savemat('/dagher/dagher11/filip/Obesity_maps/data/HCPA_CT_DKT_RH.mat', 
                 {'HCPA_CT_DKT_RH': mymap_parc})

# %% [markdown]
# ## Use Cammoun parcellation for BMI data - DBM

# %%
from netneurotools import datasets as nntdatasets
from neuromaps import datasets as nmdatasets
from neuromaps.parcellate import Parcellater
import pandas as pd
from neuromaps import transforms
import neuromaps
import numpy as np



cammoun = nntdatasets.fetch_cammoun2012(version="MNI152NLin2009aSym")
info = pd.read_csv(cammoun['info'])
labels = info.query('scale=="scale125"')['label']  # or might be "labels"

parc = Parcellater(cammoun['scale125'], 'mni152')  # assuming mymap is in mni152 space
BMI = neuromaps.images.load_nifti('/dagher/dagher9/filip/DBM/HCP_DBM_Slvl/beta_0003.nii')

mymap_parc = parc.fit_transform(BMI, 'mni152')

np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/BMI_DBM_Cammoun125_LH_RH.csv', mymap_parc[0], delimiter=',', fmt='%f')

# %%
info.to_csv('/dagher/dagher11/filip/Obesity_maps/data/Cammoun_labels.csv')

# %%
parc

# %% [markdown]
# ## SA and CT

# %%
from netneurotools import datasets as nntdatasets
from neuromaps import datasets as nmdatasets
from neuromaps.parcellate import Parcellater
import pandas as pd
from neuromaps import transforms
import neuromaps
import numpy as np



cammoun = nntdatasets.fetch_cammoun2012(version="fsaverage")
#info = pd.read_csv(cammoun['info'])
#labels = info.query('scale=="scale125"')['label']  # or might be "labels"
cammoun_gifti=neuromaps.images.annot_to_gifti(cammoun['scale125'])

parc = Parcellater(cammoun_gifti, 'fsaverage')  # assuming mymap is in mni152 space

BMI=transforms.fsaverage_to_fsaverage('/dagher/dagher11/filip/Obesity_maps/data/BMI_rh.gii', '164k', hemi='L')
mymap_parc = parc.fit_transform(BMI, 'fsaverage', hemi='L')

np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/BMI_thickness_Cammoun125_RH.csv', mymap_parc, delimiter=',', fmt='%f')

# %%
from nibabel import freesurfer

BMI_HCP=list(['/dagher/dagher11/filip/Obesity_maps/data/BMI_rh.gii'])

BMI_ctx=transforms.fsaverage_to_fsaverage(BMI_HCP, '164k', hemi='L')
BMI=BMI_ctx[0].agg_data()

Cammoun125=freesurfer.io.read_annot('/home/bic/fmorys/nnt-data/atl-cammoun2012/fsaverage/atl-Cammoun2012_space-fsaverage_res-125_hemi-R_deterministic.annot')[0]

BMI_Cammoun125=list()

for i in range(110):
    BMI_Cammoun125.append(np.average(BMI[Cammoun125==i]))
    
BMI_Cammoun125.pop(0)
BMI_Cammoun125.pop(3)

np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/BMI_thickness_Cammoun125_RH.csv', BMI_Cammoun125, delimiter=',', fmt='%f')

# %%
from netneurotools import datasets as nntdatasets
from neuromaps import datasets as nmdatasets
from neuromaps.parcellate import Parcellater
import pandas as pd
from neuromaps import transforms
import neuromaps
import numpy as np



cammoun = nntdatasets.fetch_cammoun2012(version="fsaverage")
#info = pd.read_csv(cammoun['info'])
#labels = info.query('scale=="scale125"')['label']  # or might be "labels"
cammoun_gifti=neuromaps.images.annot_to_gifti(cammoun['scale125'])

parc = Parcellater(cammoun_gifti, 'fsaverage')  # assuming mymap is in mni152 space

BMI=transforms.fsaverage_to_fsaverage('/dagher/dagher11/filip/Obesity_maps/data/BMI_area_lh.gii', '164k', hemi='L')
mymap_parc = parc.fit_transform(BMI, 'fsaverage', hemi='L')

np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/BMI_area_Cammoun125.csv', mymap_parc, delimiter=',', fmt='%f')
# Out:
# /dagher/dagher12/filip/software/miniconda3py/envs/py3/lib/python3.10/site-packages/nilearn/input_data/__init__.py:27: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## Both hemispheres CT

# %%
from netneurotools import datasets as nntdatasets
from neuromaps import datasets as nmdatasets
from neuromaps.parcellate import Parcellater
import pandas as pd
from neuromaps import transforms
import neuromaps
import numpy as np



cammoun = nntdatasets.fetch_cammoun2012(version="fsaverage")
#info = pd.read_csv(cammoun['info'])
#labels = info.query('scale=="scale125"')['label']  # or might be "labels"
cammoun_gifti=neuromaps.images.annot_to_gifti(cammoun['scale125'])

parc = Parcellater(cammoun_gifti, 'fsaverage')  

BMI=transforms.fsaverage_to_fsaverage(['/dagher/dagher11/filip/Obesity_maps/data/BMI_lh.gii',
                                       '/dagher/dagher11/filip/Obesity_maps/data/BMI_rh.gii'], 
                                      '164k')
mymap_parc = parc.fit_transform(BMI, 'fsaverage')

np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/BMI_thickness_Cammoun125_LHRH.csv', mymap_parc, delimiter=',', fmt='%f')
# Out:
# /dagher/dagher12/filip/software/miniconda3py/envs/py3/lib/python3.10/site-packages/nilearn/input_data/__init__.py:27: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## Education regressor for sanity checks

# %%
from netneurotools import datasets as nntdatasets
from neuromaps import datasets as nmdatasets
from neuromaps.parcellate import Parcellater
import pandas as pd
from neuromaps import transforms
import neuromaps
import numpy as np



cammoun = nntdatasets.fetch_cammoun2012(version="fsaverage")
#info = pd.read_csv(cammoun['info'])
#labels = info.query('scale=="scale125"')['label']  # or might be "labels"
cammoun_gifti=neuromaps.images.annot_to_gifti(cammoun['scale125'])

parc = Parcellater(cammoun_gifti, 'fsaverage')  

Edu=transforms.fsaverage_to_fsaverage(['/dagher/dagher11/filip/Obesity_maps/data/edu_lh.gii'], 
                                      '164k',hemi="L")
mymap_parc = parc.fit_transform(Edu, 'fsaverage', hemi='L')

np.savetxt('/dagher/dagher11/filip/Obesity_maps/data/Edu_thickness_Cammoun125_LH.csv', mymap_parc, delimiter=',', fmt='%f')
